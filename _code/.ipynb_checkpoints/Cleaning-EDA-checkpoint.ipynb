# %% [markdown]
# # Imports, Read in data

# %%
from collections import Counter
import plotly.express as pxn
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sb # data visualization library  
import random
import plotly.graph_objects as go
from wordcloud import WordCloud,STOPWORDS
# %matplotlib inline
# Allows full width row text in column
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-13-cf12ae8fce29>:12: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
data = pd.read_csv('/Users/rashidbaset/Code/twitter-sentiment-prediction/_data/raw-data/Tweets.csv')

# %% [markdown]
# # Termonology

# %% [markdown]
# | Category                       | Definition                                                       |
# | ------------------------------ | ---------------------------------------------------------------- |
# | 'tweet_id'                     |            |
# | 'airline_sentiment'            | Negative/neutral/positive Airline sentiment confidence sentiment of tweet (target variable)                             |
# | 'airline_sentiment_confidence' | Confidence with which the given sentiment was determined         |
# | 'negativereason'               | Reason for which user posted a negative tweet                    |
# | 'negativereason_confidence'    | Confidence with which the negative reason of tweet was predicted |
# | 'airline'                      | Airline for which the tweet was posted                           |
# | 'airline_sentiment_gold'       |                                                                  |
# | 'name'                         | Name of the person who tweeted                                   |
# | 'negativereason_gold'          |                                                                  |
# | 'retweet_count'                | Number of retweets                                               |
# | 'text'                         | Text of the tweet whose sentiment has to be predicted            |
# | 'tweet_coord'                  |                                                                  |
# | 'tweet_created'                | Time at which the tweet was created                              |
# | 'tweet_location'               | Location from where the tweet was posted                         |
# | 'user_timezone'                |                                                                  |
# |                                |                                                                  |

# %% [markdown]
# The categories i'm paying attention to are:
# - 'airline_sentiment'
# - 'negativereason'
# - 'airline'
# - 'text'
# - 'tweet_created'
# - 'tweet_location'
# - 'user_timezone'

# %% [markdown]
# # Variable type table

# %% [markdown]
# | Quantitative: | Continuous                                                                   | Discrete |
# | ------------- | ---------------------------------------------------------------------------- | -------- |
# |               | 'airline_sentiment_confidence', 'negativereason_confidence', 'retweet_count' |    'tweet_created'      |
# |               |                                                                              |          |
#
# | Categorical: | Ordinal                                                        | Nominal                    |
# | ------------ | -------------------------------------------------------------- | -------------------------- |
# |              | 'arline_sentiment', 'negativereason', 'airline_sentiment_gold' | 'airline', 'user_timezone' |
# |              |                                                                |                            |

# %% [markdown]
# # Train split

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(data,test_size=0.3)

df = train

# %% [markdown]
# # df.info() & value_counts()

# %%
df.describe()
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  6.367000e+03  6367.000000                   6367.000000
# mean   5.692552e+17  0.933948                      0.733100
# std    7.574384e+14  0.137427                      0.237922
# min    5.675900e+17  0.339400                      0.312200
# 25%    5.686411e+17  1.000000                      0.645800
# 50%    5.695318e+17  1.000000                      0.680900
# 75%    5.698714e+17  1.000000                      1.000000
# max    5.703088e+17  1.000000                      1.000000
#
#        retweet_count
# count  6367.000000
# mean   0.099733
# std    0.922003
# min    0.000000
# 25%    0.000000
# 50%    0.000000
# 75%    0.000000
# max    44.000000

# %%
df.shape
# Out:
# (6367, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10248 entries, 864 to 5904
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      10248 non-null  int64
#  1   airline_sentiment             10248 non-null  object
#  2   airline_sentiment_confidence  10248 non-null  float64
#  3   negativereason                6367 non-null   object
#  4   negativereason_confidence     7309 non-null   float64
#  5   airline                       10248 non-null  object
#  6   airline_sentiment_gold        27 non-null     object
#  7   name                          10248 non-null  object
#  8   negativereason_gold           21 non-null     object
#  9   retweet_count                 10248 non-null  int64
#  10  text                          10248 non-null  object
#  11  tweet_coord                   726 non-null    object
#  12  tweet_created                 10248 non-null  object
#  13  tweet_location                6927 non-null   object
#  14  user_timezone                 6899 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 1.3+ MB

# %%
# Missing Data

df.isna().sum()
na_counts = df.isna().sum()
base_color = sb.color_palette()[0]
sb.barplot(na_counts, na_counts.index.values, color=base_color)

# %%
## Cols to Remove?
### Dropping cols
# df.drop(columns=['tweet_coord', 'negativereason_gold', 'airline_sentiment_gold'], axis=1, inplace=True)

# %%
### Date type conversion
df['tweet_created'] = df['tweet_created'].astype('datetime64[ns]')
# Out:
# <ipython-input-19-8a48f0141564>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet_created'] = df['tweet_created'].astype('datetime64[ns]')

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['negativereason',
#  'negativereason_confidence',
#  'airline_sentiment_gold',
#  'negativereason_gold',
#  'tweet_coord',
#  'tweet_location',
#  'user_timezone']

# %%
df.loc[:, df.isna().any()]
# Out:
#                     negativereason  negativereason_confidence  \
# 864    NaN                         NaN
# 4800   Flight Attendant Complaints  0.6568
# 12327  NaN                          0.0000
# 161    Cancelled Flight             1.0000
# 7284   NaN                         NaN
# ...    ...                          ..
# 2320   Can't Tell                   0.6951
# 2445   Customer Service Issue       1.0000
# 2827   Bad Flight                   1.0000
# 14577  Customer Service Issue       0.3451
# 5904   NaN                         NaN
#
#       airline_sentiment_gold negativereason_gold  \
# 864    NaN                    NaN
# 4800   NaN                    NaN
# 12327  NaN                    NaN
# 161    NaN                    NaN
# 7284   NaN                    NaN
# ...    ...                    ...
# 2320   NaN                    NaN
# 2445   NaN                    NaN
# 2827   NaN                    NaN
# 14577  NaN                    NaN
# 5904   NaN                    NaN
#
#                         tweet_coord                 tweet_location  \
# 864    NaN                           CA
# 4800   NaN                           Lincoln, NE
# 12327  NaN                           iPhone: 37.621227,-122.386002
# 161    NaN                           Brooklyn
# 7284   NaN                           NaN
# ...    ...                           ...
# 2320   NaN                           NaN
# 2445   NaN                           NaN
# 2827   NaN                           Salt Lake City, UT
# 14577  [33.93939612, -118.38973148]  Santa Monica, CA
# 5904   [30.20654541, -97.74890436]   Texas
#
#                      user_timezone
# 864    Eastern Time (US & Canada)
# 4800   Central Time (US & Canada)
# 12327  Eastern Time (US & Canada)
# 161    Eastern Time (US & Canada)
# 7284   NaN
# ...    ...
# 2320   Atlantic Time (Canada)
# 2445   NaN
# 2827   Mountain Time (US & Canada)
# 14577  Pacific Time (US & Canada)
# 5904   Mountain Time (US & Canada)
#
# [10248 rows x 7 columns]

# %%
df.isna().sum()
na_counts = df.isna().sum()
base_color = sb.color_palette()[0]
sb.barplot(na_counts, na_counts.index.values, color=base_color)

# %%
df.dropna(subset=['negativereason'], inplace=True)
# Out:
# <ipython-input-26-a82cdfc919a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['negativereason'], inplace=True)

# %%
df.isna().sum()
na_counts = df.isna().sum()
base_color = sb.color_palette()[0]
sb.barplot(na_counts, na_counts.index.values, color=base_color)

# %%
df.to_csv("/Users/rashidbaset/Code/twitter-sentiment-prediction/_data/processed/airline_sentiment_cleaned.csv")

# %% [markdown]
# ## Airlines

# %%
df.airline.value_counts()
# Out:
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America    504
# Name: airline, dtype: int64

# %% [markdown]
# ### Differences in cofidence for airline sentiment and negative reason

# %%
sb.lineplot(data=df, x="airline", y="airline_sentiment_confidence")

# %%
sb.lineplot(data=df, x="airline", y="negativereason_confidence")

# %% [markdown]
# ## Users

# %%
df.name.value_counts()
# Out:
# JetBlueNews     63
# kbosspotter     32
# _mhertz         29
# otisday         28
# throthra        27
#                 ..
# sklovek1        1
# nujoud          1
# hill43          1
# Traceyd14       1
# davegoldfarb    1
# Name: name, Length: 7701, dtype: int64

# %% [markdown]
# ## Retweet count

# %%
df.retweet_count.value_counts()
# Out:
# 0     13873
# 1     640
# 2     66
# 3     22
# 4     17
# 5     5
# 7     3
# 6     3
# 22    2
# 8     1
# 32    1
# 9     1
# 31    1
# 18    1
# 15    1
# 28    1
# 44    1
# 11    1
# Name: retweet_count, dtype: int64

# %% [markdown]
# ## Tweet location

# %%
df.tweet_location.value_counts()
# Out:
# Boston, MA                        157
# New York, NY                      156
# Washington, DC                    150
# New York                          127
# USA                               126
#                                  ...
# Fife, Dunfermline                 1
# Barrie | Ontario | Canada         1
# Bloomington, MN                   1
# Location: constantly changing!    1
# Marblehead, MA                    1
# Name: tweet_location, Length: 3081, dtype: int64

# %% [markdown]
# ## User timezone

# %%
df.user_timezone.value_counts()
# Out:
# Eastern Time (US & Canada)    3744
# Central Time (US & Canada)    1931
# Pacific Time (US & Canada)    1208
# Quito                         738
# Atlantic Time (Canada)        497
#                              ...
# Lisbon                        1
# EST                           1
# Saskatchewan                  1
# Pretoria                      1
# Tokyo                         1
# Name: user_timezone, Length: 85, dtype: int64

# %% [markdown]
# # Target variable

# %%
## Bar chart of Count & Proportion for target variable  
base_color = sb.color_palette()[0]
sb.countplot(data = df, x= 'airline_sentiment', color = base_color,
             order = ['positive', 'neutral', 'negative']);
#### add annotations
n_points = df.shape[0]
cat_counts = df['airline_sentiment'].value_counts()
locs, labels = plt.xticks()  # get the current tick locations and labels
#### loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    #### get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    #### print the annotation just below the top of the bar
    plt.text(loc, count-559, pct_string, ha='center', color='w')

# %%
data.airline_sentiment.value_counts().plot(kind='pie', autopct='%1.0f%%')

# %% [markdown]
# The target variable is imbalanced toward the negative class however we may have enough positive labeled tweets. We will find out when we test model performance.

# %% [markdown]
# # Customer Sentiment Comparison for each Airline

# %%
df.airline.value_counts().plot(kind='pie', autopct='%1.0f%%')

# %%
ct = pd.crosstab(df.airline, df.airline_sentiment)

ct.sort_values(by='negative', ascending=True).plot.bar(stacked=True)

# %% [markdown]
# Looking at the data as is, we see United having the most negative tweets. When looking at the data as an aggregate however as shown in the next chart, US Airways tops the negative list. The key takeaway here is that considering all things being equal with respect to count paints a different picture in that we consider everyhing as a whole instead of individually.

# %%
air_sen=pd.crosstab(df.airline, df.airline_sentiment)
#air_sen.sort_values('airline_sentiment', ascending=True)

air_sen.sort_index(ascending=True)

#air_sen
# Out:
# airline_sentiment  negative
# airline
# American           1377
# Delta              667
# Southwest          807
# US Airways         1582
# United             1804
# Virgin America     130

# %%
data = pd.DataFrame(data=df, columns=['airline','airline_sentiment'])

# %%
ct = pd.crosstab(df.airline, df.airline_sentiment, normalize='index')

ct.sort_values(by='negative', ascending=True).plot.bar(stacked=True)

# %%
g = sb.FacetGrid(df, col="airline")
g.map(sb.countplot,"airline_sentiment")
# Out:
# /Users/rashidbaset/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # What are customers specifically unhappy about

# %%
new_df=df[df['airline_sentiment']=='negative']
words = ' '.join(new_df['text'])
cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)
plt.figure(1,figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
words = ' '.join(df['negativereason'])

cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(cleaned_word)
plt.figure(1,figsize=(12, 12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-31c1fdf7e37c> in <module>
# ----> 1 words = ' '.join(df['negativereason'])
#       2
#       3 cleaned_word = " ".join([word for word in words.split()
#       4                             if 'http' not in word
#       5                                 and not word.startswith('@')
#
# TypeError: sequence item 0: expected str instance, float found

# %%
#Visualize how many tweets per negative reasons
colors = sb.color_palette('husl',10)
df.negativereason.value_counts().plot(kind='barh',figsize=(8,8))
plt.xlabel('Frequency')
plt.ylabel('Negative Reasons')
# Out:
# Text(0, 0.5, 'Negative Reasons')

# %%
g = sb.FacetGrid(df, col="airline")
g1 = g.map(sb.countplot,"negativereason")
g1.set_xticklabels(rotation=90)
# Out:
# /Users/rashidbaset/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#Visualize negative reasons in precentage per airline
colors=sb.color_palette("husl",10)
pd.crosstab(df.airline, df.negativereason).apply(lambda x: x/x.sum() * 100, axis=1).plot(kind="bar",figsize=(8,8),stacked=True)
plt.title('The Reasons Customers React Negatively to Each Airline in Percentage', fontsize=18)
plt.xlabel('Airline')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

# %% [raw]
# # Explore Hashtag and emojis

# %% [markdown]
# # Track sentiment over time

# %%
date = df.reset_index()
#convert the Date column to pandas datetime
date.tweet_created = pd.to_datetime(date.tweet_created)
#Reduce the dates in the date column to only the date and no time stamp using the 'dt.date' method
date.tweet_created = date.tweet_created.dt.date
date.tweet_created.head()
df = date
day_df = df.groupby(['tweet_created','airline','airline_sentiment']).size()
# day_df = day_df.reset_index()
day_df
# Out:
# tweet_created  airline         airline_sentiment
# 2015-02-17     Delta           negative             51
#                                neutral              63
#                                positive             47
#                Southwest       negative             162
#                                neutral              69
#                                                     ..
# 2015-02-24     United          neutral              88
#                                positive             55
#                Virgin America  negative             15
#                                neutral              15
#                                positive             19
# Length: 133, dtype: int64

# %%
day_df = day_df.loc(axis=0)[:,:,'negative']

#groupby and plot data
ax2 = day_df.groupby(['tweet_created','airline']).sum().unstack().plot(kind = 'bar', color=['red', 'green', 'blue','yellow','purple','orange'], figsize = (15,6), rot = 70)
labels = ['American','Delta','Southwest','US Airways','United','Virgin America']
ax2.legend(labels = labels)
ax2.set_xlabel('Date')
ax2.set_ylabel('Negative Tweets')
plt.show()

# %%
df['tweet_created'] = pd.to_datetime(df.tweet_created)
# Out:
# <ipython-input-47-068fa9c211ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet_created'] = pd.to_datetime(df.tweet_created)

# %%
df['tweet_created_hour'] = df.tweet_created.dt.hour
pf = df.groupby(['tweet_created_hour']).negativereason.value_counts()
pf.unstack()
# Out:
# <ipython-input-48-a1d71b98756a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet_created_hour'] = df.tweet_created.dt.hour
# negativereason      Bad Flight  Can't Tell  Cancelled Flight  \
# tweet_created_hour
# 0                   23.0        43.0        29.0
# 1                   23.0        40.0        20.0
# 2                   17.0        37.0        26.0
# 3                   22.0        45.0        23.0
# 4                   16.0        34.0        25.0
# 5                   9.0         21.0        19.0
# 6                   11.0        15.0        13.0
# 7                   2.0         15.0        9.0
# 8                   6.0         10.0        7.0
# 9                   3.0         11.0        2.0
# 10                  2.0         9.0         6.0
# 11                  9.0         11.0        14.0
# 12                  9.0         25.0        13.0
# 13                  18.0        15.0        24.0
# 14                  24.0        39.0        21.0
# 15                  18.0        39.0        40.0
# 16                  26.0        41.0        36.0
# 17                  24.0        46.0        47.0
# 18                  23.0        51.0        31.0
# 19                  33.0        58.0        34.0
# 20                  18.0        30.0        39.0
# 21                  21.0        56.0        48.0
# 22                  22.0        55.0        35.0
# 23                  17.0        56.0        31.0
#
# negativereason      Customer Service Issue  Damaged Luggage  \
# tweet_created_hour
# 0                   96.0                   NaN
# 1                   72.0                    3.0
# 2                   113.0                   3.0
# 3                   90.0                    3.0
# 4                   80.0                    4.0
# 5                   54.0                    1.0
# 6                   47.0                    1.0
# 7                   27.0                    1.0
# 8                   20.0                   NaN
# 9                   18.0                    2.0
# 10                  32.0                   NaN
# 11                  38.0                    1.0
# 12                  57.0                   NaN
# 13                  82.0                    1.0
# 14                  105.0                   1.0
# 15                  112.0                   2.0
# 16                  145.0                   1.0
# 17                  141.0                   6.0
# 18                  114.0                   1.0
# 19                  109.0                   3.0
# 20                  110.0                   3.0
# 21                  126.0                   4.0
# 22                  128.0                   6.0
# 23                  99.0                    4.0
#
# negativereason      Flight Attendant Complaints  Flight Booking Problems  \
# tweet_created_hour
# 0                   16.0                         13.0
# 1                   17.0                         18.0
# 2                   16.0                         20.0
# 3                   19.0                         15.0
# 4                   19.0                         17.0
# 5                   11.0                         14.0
# 6                   9.0                          11.0
# 7                   4.0                          6.0
# 8                   4.0                          2.0
# 9                   1.0                         NaN
# 10                  11.0                         1.0
# 11                  3.0                          3.0
# 12                  12.0                         9.0
# 13                  15.0                         13.0
# 14                  14.0                         12.0
# 15                  18.0                         21.0
# 16                  12.0                         25.0
# 17                  36.0                         22.0
# 18                  17.0                         26.0
# 19                  25.0                         28.0
# 20                  11.0                         21.0
# 21                  16.0                         26.0
# 22                  19.0                         24.0
# 23                  18.0                         20.0
#
# negativereason      Late Flight  Lost Luggage  longlines
# tweet_created_hour
# 0                   83.0         27.0          11.0
# 1                   81.0         29.0          9.0
# 2                   69.0         25.0          2.0
# 3                   80.0         36.0          7.0
# 4                   47.0         28.0          6.0
# 5                   31.0         20.0          2.0
# 6                   24.0         22.0          2.0
# 7                   16.0         13.0          2.0
# 8                   6.0          13.0         NaN
# 9                   7.0          8.0           1.0
# 10                  9.0          11.0          2.0
# 11                  14.0         11.0          4.0
# 12                  27.0         15.0          2.0
# 13                  43.0         14.0         NaN
# 14                  42.0         17.0          6.0
# 15                  65.0         12.0          5.0
# 16                  72.0         21.0          8.0
# 17                  60.0         29.0          8.0
# 18                  64.0         29.0          9.0
# 19                  65.0         17.0          12.0
# 20                  59.0         27.0          7.0
# 21                  53.0         29.0          4.0
# 22                  75.0         31.0          6.0
# 23                  83.0         21.0          6.0

# %%
my_plot = pf.unstack().plot(kind='bar',stacked=True,figsize=(18, 8),rot=0)

my_plot.set_title("Negetive Reasons by Time", fontsize=20)
my_plot.set_xlabel("Time")
my_plot.set_ylabel("Negative Reason")
my_plot.legend(loc='right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
df.user_timezone.value_counts().plot(kind='pie', autopct='%1.0f%%',figsize=(8,8))

# %% [markdown]
# # Determine if particular segments feel more strongly about airline. Can we determine key promoters and detractors?

# %% [markdown]
# # Track how a change in service affects how customers feel.
