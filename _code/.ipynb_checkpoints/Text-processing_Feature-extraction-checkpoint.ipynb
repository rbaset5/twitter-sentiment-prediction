# %%
import numpy as np # linear algebra
import pandas as pd #

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/rashidbaset/Code/twitter-sentiment-prediction/_data/processed/airline_sentiment_cleaned.csv")

# %%
df
# Out:
#        Unnamed: 0            tweet_id airline_sentiment  \
# 0             345  568532221180534784          negative
# 1           10698  568966330315091968          negative
# 2            3718  568170840174538752          negative
# 3             840  570055898367799296          negative
# 4            3764  568144589162287105          negative
# ...           ...                 ...               ...
# 10243        3810  568108909480824832           neutral
# 10244       14028  569676217432977408          negative
# 10245       10229  569478023839416320          negative
# 10246       11424  568127477555441664          negative
# 10247        9284  570007761355980800          negative
#
#        airline_sentiment_confidence           negativereason  \
# 0                            0.6558              Late Flight
# 1                            1.0000              Late Flight
# 2                            1.0000   Customer Service Issue
# 3                            1.0000         Cancelled Flight
# 4                            1.0000   Customer Service Issue
# ...                             ...                      ...
# 10243                        1.0000                      NaN
# 10244                        1.0000  Flight Booking Problems
# 10245                        1.0000   Customer Service Issue
# 10246                        1.0000   Customer Service Issue
# 10247                        1.0000             Lost Luggage
#
#        negativereason_confidence         airline             name  \
# 0                         0.6558  Virgin America       bonniecamp
# 1                         1.0000      US Airways       RTriplette
# 2                         0.6752          United           qlyss8
# 3                         0.3417          United  kimberlytwaters
# 4                         0.3471          United      JeffPfeifer
# ...                          ...             ...              ...
# 10243                        NaN          United       BWithering
# 10244                     0.6669        American     reebokpumped
# 10245                     0.6657      US Airways   JulesMonacelli
# 10246                     1.0000      US Airways      Twinscream1
# 10247                     0.6941      US Airways         Gregm528
#
#        retweet_count                                               text  \
# 0                  1  @VirginAmerica spending my birthday night with...
# 1                  0  @USAirways flight #3797 treatment of passenger...
# 2                  0  “@united: @qlyss8 We don't want our customers ...
# 3                  0  @united I'm very frustrated and have wasted 2 ...
# 4                  0  @united What's up with the reduction in E+ on ...
# ...              ...                                                ...
# 10243              0  @united How much is baggage check for Internat...
# 10244              0  @americanair seriously, pls pls bring more peo...
# 10245              0  @USAirways now on hold for 2 hrs 20 min. This ...
# 10246              0  @USAirways I have sent letter after letter and...
# 10247              1  @USAirways @Gregm528 well there is certainly n...
#
#              tweet_created      tweet_location                user_timezone
# 0      2015-02-19 22:06:59                 NaN                          NaN
# 1      2015-02-21 02:51:58   DC - SF - NC - MA                          NaN
# 2      2015-02-18 22:10:59          Texas, USA  Mountain Time (US & Canada)
# 3      2015-02-24 03:01:31      Gainesville GA       Atlantic Time (Canada)
# 4      2015-02-18 20:26:40          Denver, CO  Mountain Time (US & Canada)
# ...                    ...                 ...                          ...
# 10243  2015-02-18 18:04:53  Raleigh, NC  SoCal   Eastern Time (US & Canada)
# 10244  2015-02-23 01:52:48           Milwaukee   Central Time (US & Canada)
# 10245  2015-02-22 12:45:15       Rochester, NY   Eastern Time (US & Canada)
# 10246  2015-02-18 19:18:40                 NaN                          NaN
# 10247  2015-02-23 23:50:15                  NY   Eastern Time (US & Canada)
#
# [10248 rows x 13 columns]

# %%
categorical_variables = ['airline_sentiment', 'negativereason', 'airline']

# %%
from sklearn.preprocessing import OneHotEncoder

from sklearn.compose import ColumnTransformer

# %%
## create an encoder object. This will help us to convert
## categorical variables to new columns
encoder = OneHotEncoder(handle_unknown= 'error',
                        drop='first',
                        categories= 'auto' )

## Create an columntransformer object.
## This will help us to merge transformed columns
## with the rest of the dataset.

ct = ColumnTransformer(transformers =[('ohe', encoder, categorical_variables)], remainder= 'passthrough')
ct.fit(df[x_cols])
X = ct.transform(df[x_cols])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae3788a75a3d> in <module>
#      10
#      11 ct = ColumnTransformer(transformers =[('ohe', encoder, categorical_variables)], remainder= 'passthrough')
# ---> 12 ct.fit(df[x_cols])
#      13 X = ct.transform(df[x_cols])
#
# NameError: name 'x_cols' is not defined
