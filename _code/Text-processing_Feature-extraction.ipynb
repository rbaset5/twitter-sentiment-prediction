# %%
import numpy as np # linear algebra
import pandas as pd #

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/rashidbaset/Code/twitter-sentiment-prediction/_data/processed/airline_sentiment_cleaned.csv")

# %%
df
# Out:
#       Unnamed: 0            tweet_id airline_sentiment  \
# 0           4800  569716065741045760          negative
# 1            161  569564610837086209          negative
# 2           4225  567767199700758530          negative
# 3           3968  567900686089719812          negative
# 4           5263  569226128168062976          negative
# ...          ...                 ...               ...
# 6362       12675  570065545392861184          negative
# 6363        2320  569259575800569857          negative
# 6364        2445  569202773704646658          negative
# 6365        2827  568882079091400705          negative
# 6366       14577  569596515510956032          negative
#
#       airline_sentiment_confidence               negativereason  \
# 0                           1.0000  Flight Attendant Complaints
# 1                           1.0000             Cancelled Flight
# 2                           1.0000                   Bad Flight
# 3                           1.0000                   Can't Tell
# 4                           1.0000       Customer Service Issue
# ...                            ...                          ...
# 6362                        1.0000                   Can't Tell
# 6363                        1.0000                   Can't Tell
# 6364                        1.0000       Customer Service Issue
# 6365                        1.0000                   Bad Flight
# 6366                        0.6694       Customer Service Issue
#
#       negativereason_confidence         airline airline_sentiment_gold  \
# 0                        0.6568       Southwest                    NaN
# 1                        1.0000  Virgin America                    NaN
# 2                        0.6481          United                    NaN
# 3                        0.6649          United                    NaN
# 4                        0.6737       Southwest                    NaN
# ...                         ...             ...                    ...
# 6362                     1.0000        American                    NaN
# 6363                     0.6951          United                    NaN
# 6364                     1.0000          United                    NaN
# 6365                     1.0000          United                    NaN
# 6366                     0.3451        American                    NaN
#
#                  name negativereason_gold  retweet_count  \
# 0           wittmania                 NaN              0
# 1           finslippy                 NaN              0
# 2     DGomezPearlberg                 NaN              1
# 3          coolingpie                 NaN              0
# 4       lynnhambutler                 NaN              0
# ...               ...                 ...            ...
# 6362       JasonShaw2                 NaN              4
# 6363     jcharvardapp                 NaN              0
# 6364      hadAbadWeek                 NaN              0
# 6365       justindoll                 NaN              1
# 6366       angiedrich                 NaN              0
#
#                                                    text  \
# 0     @SouthwestAir broke the stroller my wife and b...
# 1     @VirginAmerica our flight into lga was Cancell...
# 2     @united its 2015 and no power outlets at the s...
# 3          @united do you guys have any working planes?
# 4     @SouthwestAir fl 4158 Cancelled Flightled from...
# ...                                                 ...
# 6362  @AmericanAir this is the biggest joke I've eve...
# 6363  @united no bag tagging, led to many people bac...
# 6364  @united customers ✅. Customer service ❌ http:/...
# 6365  @united Thank U for the 1hr delay then boardin...
# 6366  @AmericanAir I have never on all my trips on a...
#
#                        tweet_coord        tweet_created  \
# 0                              NaN  2015-02-23 04:31:09
# 1                              NaN  2015-02-22 18:29:19
# 2      [40.70749747, -74.17084113]  2015-02-17 19:27:03
# 3                              NaN  2015-02-18 04:17:29
# 4                              NaN  2015-02-21 20:04:19
# ...                            ...                  ...
# 6362                           NaN  2015-02-24 03:39:51
# 6363                           NaN  2015-02-21 22:17:13
# 6364                           NaN  2015-02-21 18:31:31
# 6365                           NaN  2015-02-20 21:17:11
# 6366  [33.93939612, -118.38973148]  2015-02-22 20:36:06
#
#               tweet_location                user_timezone
# 0                Lincoln, NE   Central Time (US & Canada)
# 1                   Brooklyn   Eastern Time (US & Canada)
# 2                        NYC   Eastern Time (US & Canada)
# 3     the questions district   Eastern Time (US & Canada)
# 4                        NaN                          NaN
# ...                      ...                          ...
# 6362              Belleville   Eastern Time (US & Canada)
# 6363                     NaN       Atlantic Time (Canada)
# 6364                     NaN                          NaN
# 6365      Salt Lake City, UT  Mountain Time (US & Canada)
# 6366        Santa Monica, CA   Pacific Time (US & Canada)
#
# [6367 rows x 16 columns]

# %%
x_cols = ['airline_sentiment', 'negativereason', 'airline']

# %%
from sklearn.preprocessing import OneHotEncoder

from sklearn.compose import ColumnTransformer

# %%
## create an encoder object. This will help us to convert
## categorical variables to new columns
encoder = OneHotEncoder(handle_unknown= 'error',
                        drop='first',
                        categories= 'auto' )

## Create an columntransformer object.
## This will help us to merge transformed columns
## with the rest of the dataset.

ct = ColumnTransformer(transformers =[('ohe', encoder, categorical_variables)], remainder= 'passthrough')
ct.fit(df[x_cols])
X = ct.transform(df[x_cols])
